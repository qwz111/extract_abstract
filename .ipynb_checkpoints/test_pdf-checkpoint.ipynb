# %%
import pdfplumber
import pandas as pd
 
path = 'test3.pdf'    

with pdfplumber.open(path) as pdf: 
    content = ''
    for i in range(len(pdf.pages)):
    	# 读取PDF文档第i+1页
        page = pdf.pages[i] 
 
        # page.extract_text()函数即读取文本内容，下面这步是去掉文档最下面的页码
        page_content = '\n'.join(page.extract_text().split('\n')[:-1])
        content = content + page_content
 
 
# # 提取以上解析结果中，“地方法规”和“2.其他有关资料”之间的内容
# result = content.split('地方法规列举如下：')[1].split('2.其他有关资料')[0]

# %%
# content = content.replace(' ','')
content = content.replace('\n','')
content
# Out:
# '中国电机工程学报 Proceedings of the CSEE ISSN 0258-8013,CN 11-2107/TM     《中国电机工程学报》网络首发论文  题目：  人工智能技术在新能源功率预测的应用及展望 作者：  朱琼锋，李家腾，乔骥，史梦洁，王朝亮 DOI：  10.13334/j.0258-8013.pcsee.213114 网络首发日期：  2022-04-26 引用格式：  朱琼锋，李家腾，乔骥，史梦洁，王朝亮．人工智能技术在新能源功率预测的应用及展望[J/OL]．中国电机工程学报. https://doi.org/10.13334/j.0258-8013.pcsee.213114       网络首发：在编辑部工作流程中，稿件从录用到出版要经历录用定稿、排版定稿、整期汇编定稿等阶段。录用定稿指内容已经确定，且通过同行评议、主编终审同意刊用的稿件。排版定稿指录用定稿按照期刊特定版式（包括网络呈现版式）排版后的稿件，可暂不确定出版年、卷、期和页码。整期汇编定稿指出版年、卷、期、页码均已确定的印刷或数字出版的整期汇编稿件。录用定稿网络首发稿件内容必须符合《出版管理条例》和《期刊出版管理规定》的有关规定；学术研究成果具有创新性、科学性和先进性，符合编辑部对刊文的录用要求，不存在学术不端行为及其他侵权行为；稿件内容应基本符合国家有关书刊编辑、出版的技术标准，正确使用和统一规范语言文字、符号、数字、外文字母、法定计量单位及地图标注等。为确保录用定稿网络首发的严肃性，录用定稿一经发布，不得修改论文题目、作者、机构名称和学术内容，只可基于编辑规范进行少量文字的修改。 出版确认：纸质期刊编辑部通过与《中国学术期刊（光盘版）》电子杂志社有限公司签约，在《中国学术期刊（网络版）》出版传播平台上创办与纸质期刊内容一致的网络版，以单篇或整期出版形式，在印刷出版之前刊发论文的录用定稿、排版定稿、整期汇编定稿。因为《中国学术期刊（网络版）》是国家新闻出版广电总局批准的网络连续型出版物（ISSN 2096-4188，CN 11-6037/Z），所以签约期刊的网络版上网络首发论文视为正式出版。 网络首发时间：2022-04-26 14:37:45网络首发地址：https://kns.cnki.net/kcms/detail/11.2107.TM.20220425.1645.010.html                                      中  国  电  机  工  程  学  报                                                    Proceedings of the CSEE              DOI：10.13334/j.0258-8013.pcsee.213114 人工智能技术在新能源功率预测的应用及展望 朱琼锋 1，李家腾 1*，乔骥 1，史梦洁 1，王朝亮 2 （1．中国电力科学研究院有限公司 北京市 海淀区 100192； 2. 国网浙江省电力有限公司营销服务中心 浙江省 杭州市 310000）  Application and Prospect of AI Technology in Renewable Energy Forecasting   1 1* 1 1 2ZHU Qiongfeng ，LI Jiateng ，QIAO Ji ， SHI Mengjie ，WANG Chaoliang  (1. China Electric Power Research Institute, Haidian District, Beijing 100192, China 2. State Grid Zhejiang Marketing Service Centre, Hangzhou Zhejiang 310000, China) ABSTRACT: Building a new power system dominated by  variety of AI technologies such as reinforcement learning, renewable energy is one of the main measures to achieve   meta-learning,  graph  neural  network,  to  solve  related "dual-carbon" strategic goal. Wind power and photovoltaic  problems are prospected. power generation are the two most representative renewable KEY WORDS：wind power generation; photovoltaic power energy, and their volatility and randomness have brought generation;  power  prediction;  artificial  intelligence major  challenges  to  grid  security  and  renewable  energy technology consumption, renewable energy power prediction is the key technology to reduce its random impact. In recent years,  摘要：构建以新能源为主体的新型电力系统是实现我国with the successful application of big data technology and  “双碳”战略目标的主要举措之一，风力发电和光伏发电the latest AI technology represented by deep learning and  作为两种最具代表性的新能源，其波动性和随机性给电网reinforcement learning in many fields, Its application in  安全和新能源消纳带来了重大挑战，新能源功率预测是降renewable energy power forecasting is still in the ascendant.  低其随机性影响的核心关键技术。近年来随着大数据技术This paper first briefly discusses the theoretical basis of AI  和以深度学习、强化学习为代表的新一代人工智能技术在technology in the application of renewable energy power  诸多领域的成功应用，其在新能源功率预测方面的应用仍forecasting, and systematically summarizes the application  有方兴未艾之势。本文首先简要论述了人工智能技术在新of AI technology in wind power and photovoltaic power  能源功率预测应用的理论基础，并对人工智能技术在风电forecasting,  including  the  application  of  various  data  和光伏功率预测方面的应用进行了系统总结，包括数据增processing  technologies  such  as  data  enhancement  and  强和特征构建等多种数据处理技术的应用，传统机器学习feature  construction,  application  of  traditional  machine  算法、深度学习算法以及组合算法在模型构建方面的应learning, deep learning, and combined algorithms in model  用，以及进化算法、群智能优化算法、强化学习等多种智construction, and the application of evolutionary algorithm,  能优化算法在模型训练和超参数优化方面的应用。然后对swarm intelligence optimization, reinforcement learning and  当前相关文献进行了统计分析，并基于新能源预测大赛结other intelligent optimization algorithms in model training  果和实际预测系统调研情况，对当前学术界研究热点和趋and hyperparameter optimization. Then the current related  势，产业界模型应用情况进行了对比和分析。最后对当前literature was statistically analyzed, and based on the results  新能源功率预测在场景自适应、小样本学习、NWP数据of the renewable energy forecasting contest as well as the  时空分辨率、分布式新能源预测等方面存在的一些问题进actual  forecasting  system  research  situation,  the  current  行了剖析，并对采 ...

# %%
import re

ret = re.match(r"(.*)引言(.*)",content)
print(ret.group(2))
docment = ret.group(2)

# docment = content
# Out:
#  power forecasting in scene adaptation, few-shot learning, NWP data spatio-temporal resolution, distributed renewable  为落实碳达峰碳中和的能源战略目标，预计到energy prediction, etc. are analyzed, and the prospects of a 2060 年，全社会用电量超过 16 万亿千瓦时，新能基金项目：国家重点研发计划资助项目(2020YFB0905900)。 2  中  国  电  机  工  程  学  报   源发电装机达到 50 亿千瓦，新能源发电量占比将 工作量。尤其在新能源概率预测，区域预测，复杂由目前的8%提高到60%以上[1]。  时空特性关联性挖掘等特殊场景下更是具有传统风力发电和光伏发电是当前最主流的两种新 非人工智能方法不可比拟的优势。 能源发电形式，截至 2020 年底，我国风电光伏装 本文首先对人工智能技术在新能源功率预测机总量分别达2.81亿千瓦、2.53亿千瓦，同比增长 应用的理论基础进行了论述，并基于该理论框架对34.6%、24.1%。然而，由于风力发电和光伏发电受 新能源功率物理建模方法和数据驱动方法进行了气象因素、日夜周期等因素影响较大，具有强波动 简要论述和对比。 性和间歇性。高比例的新能源接入电力系统后给电 然后对人工智能技术在新能源功率预测的应网安全稳定造成了较大风险，也增加了调度运行的 用进行了总结，主要包括模型输入、模型构建和参难度。  数优化三个方面，其中模型输入包括数据预处理、新能源功率预测是降低新能源出力随机性不 数据增强和特征构建方面的应用。模型构建主要涉利影响的一项关键技术，一般基于气象预报数据、 及传统机器学习算法，代表性算法包括 SVM、新能源功率数据和气象观测数据等动态数据，结合 GBDT以及各种传统的浅层神经网络[13-15]；基于深新能源场站位置和设备参数等信息进行建模，预测 度学习的新一代人工智能技术,代表性算法包括多未来一段时间内新能源的出力变化趋势，能够有力 层卷积神经网络和循环神经网络；以及组合多种人支撑电网调度、检修计划、安稳分析、新能源消纳 工智能算法的组合预测技术[16-18]。模型参数优化包分析等多项业务开展[2-5]。未来，随着电力交易市场 括模型训练和模型超参数优化，典型算法包括遗传的成熟以及整县式光伏的大力推进，大量分布式新 算法等静态优化算法和强化学习等动态优化算法。 能源接入配电网，新能源功率预测有望进一步支撑 其次，通过选取当前新能源功率预测领域主流绿电交易、综合能源服务、需求响应等多项新型电 学术期刊近年来的相关研究文献进行统计分析，得力业务的开展[6-9]。  出了当前该领域在学术界的研究热点和趋势。由于新能源功率预测可按照不同维度进行分类，按 参考文献中所用方法的预测结果往往基于不同的照时间尺度可分为超短期、短期、中长期预测；按 预测场景，所用数据也差别很大，难以通过对文献照空间尺度可分为单机预测、单场站预测、区域预 中结果的复现来比较各方法优缺点，因此本文选取测，按预测结果可分为点预测、概率预测以及事件 了全球能源预测大赛这一较有影响力的赛事，根据预测，而按照建模方法可分为物理建模方法、时间 比赛结果排名对各方法在实际应用中的预测水平序列建模方法、基于机器学习和深度学习等人工智 进行了对比分析，由于排除了预测场景和数据差异能技术的建模方法，本文聚焦于人工智能技术建模 性，所得结论更具有客观性，具有一定参考价值，方法，图1为新能源功率预测技术框架图。  并结合实际预测系统中模型应用情况，对产业界模早期的物理建模方法过程复杂，要求建模人员 型应用情况进行了分析。 具有很强的专业领域知识并且模型参数获取难，而 最后，对新能源功率预测当前存在的问题与不时间序列预测模型非线性拟合能力和高维数据处 足进行了剖析，并结合当前新兴人工智能技术的特理能力差，因此这两类传统方法现在已较少研究。 点和优势分析，对每类问题可能的解决方案进行了近年来，以数据驱动为核心的人工智能技术得到了 展望。 快速发展，从浅层的传统机器学习算法逐步演化为1    人工智能技术新能源功率预测应用的以深度学习为代表的新一代人工智能技术，有效提理论基础 高了新能源功率预测的准确性和高效性[10-12]。 新能源功率预测问题在数学意义上的本质可相比物理建模方法、时间序列建模方法等传统从机器学习中回归任务的通用范式来理解。其目的 非人工智能方法，基于人工智能的预测模型具有诸多优点，其对高维非线性样本空间具有良好的拟合能力，同时模型参数基于数据训练得到，容易获取，模型的输入特征亦可灵活构建，结合智能优化算法                                      中  国  电  机  工  程  学  报                                                    Proceedings of the CSEE               图1  基于人工智能的新能源功率预测技术框架图 Fig. 1  Renewable energy power prediction technology framework diagram based on AI technology是构建一个最佳映射模型h，根据从输入空间中 输出空间上的期望值： 采样得到的样本 x，去预测输出空间 中对应的   E(h)L(h(x,Φ),y)dP(x,y)  (1) y。模型的输入空间对应预测模型的输入，对于目的是找到使式（1）期望风险最小的预测模新能源功率预测而言，一般包括历史功率数据、历型，即最优预测模型满足： 史气象观测数据和气象预测数据三种类型。模型输  h* argminE(h)  (2) 出空间 对应预测功率，为一维空间时对应单步h预测，为多维空间时对应多步预测。预测模型h一  求（2）式最优模型有两种思路，一种是基于般具有参数Φ，可表示为h(x,Φ)   从输入空间到输出空间 映射的先验知识直接。构建模型，此时模型的构建不需要任何数据，其精为了评价预测效果好坏，需构建一个损失函数度完全依赖于知识的准确程度，该方法对应于新能L，其实质是一个度量h(x,Φ)和 y接近程度的度量函数，L取值和h(x,Φ)与 y之间距离成正相 源功率预测的物理建模方法，物理模型中参数Φ往往都具有明确的物理含义，一般根据试验和测试手关，当h(x,Φ) y 时，L取最小。 段或者厂家产品手册取得。本文主要侧重人工智能由于损失函数只针对单个样本点的预测效果技术在新能源功率预测的应用，因此针对物理建模4  中  国  电  机  工  程  学  报   方法，仅以光伏功率预测为例进行简要论述。  因此在样本量足够的时候，通过求式（4）来逼近图2为光伏发电功率短期预测的物理方法技术 式（2）是可行的，然而当模型复杂度过高而样本路线。基本思路是利用辐照度、温度等数值天气预 量又不足时，此时可能发生过拟合，一般通过在经报数据，结合光伏电站的地理信息，采用太阳位置 验风险的基础上增加正则项J(h)来限制模型复杂模型得到光伏电池板接受到的有效辐照度，然后利 度，此时对应模型的结构风险： 用构建的光伏电池板光电转换模型和逆变器效率   E (h)Eˆ(h)J(h)  (6) s模型，得到单逆变器最终的输出功率，最后考虑线而优化目标变为： 路损耗得到光伏电站全场的发电功率。    hˆ*=argminEˆ (h)  (7) sh正则项J(h)为跟模型复杂度正相关的函数，因此求式（7）在使得经验风险最小的同时也会限制模型复杂度，从而避免过拟合发生。 新能源功率预测中数据驱动模型主要包括时间序列建模方法、基于机器学习和深度学习等人工智能技术的建模方法。对于大部分数据驱动模型而言，模型参数可分为两部分组成，Φ{,}，其中对应模型的训练参数（一般机器学习算法中简称为模型参数），而对应模型的超参数，前者主要采用特定机器学习算法训练得到，后者一般根据经验人为设定。 表1为采用物理机理建模和采用人工智能方法建模的主要区别，从中可看出，人工智能方法在建模难度、数据输入处理能力、预测的时空尺度适用性等方面均优于物理模型，但是其也存在可解释性弱，同时建模对历史数据要求较高的问题。   表1  物理模型和人工智能模型对比 Tab.1  Comparison of physical model and AI model 图2  光伏发电功率短期预测的物理方法技术路线 预测方法  物理模型  人工智能模型 Fig. 2  Physical method and technical route of photo建模难度  综合气象、电气、电子、机械等 具备多种通用模型，-voltaic power prediction 多个学科知识，专业性要求高  并配套成熟工具包，求解（2）式的另一种思路是基于数据驱动的 建模简单 方式，即依据从原始输入输出空间中采样的给定样 模型参数 基于试验测试或产品手册，参数 通过模型训练得到，获取难度  获取难度高  较为容易 本集{(x ,y ),(x ,y ), ,(x ,y )}，求使得以下1 1 2 2 m m 数据输入  NWP数据  历史功率和历史气象观测数据、NWP数据 经验风险最小的模型h： 预测空间 适用于单机建模，应用于场站和 可直接用于单机、单1 m  Eˆ(h) L(h(x ;Φ),y ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from pprint import pprint
import operator



def encode_sen(sen,corpus):
    """
    input: sentence and corpus
    output :  bag of words vector of sentence
    """
    cv = CountVectorizer()
    cv = cv.fit(corpus)
    vec = cv.transform([sen]).toarray()
    return vec[0]

def cosin_distance(vector1, vector2):
    """
    input: two bag of words vectors of sentence
    output :  the similarity between the sentence

    """
    dot_product = 0.0
    normA = 0.0
    normB = 0.0
    for a, b in zip(vector1, vector2):
        dot_product += a * b
        normA += a ** 2
        normB += b ** 2
    if normA == 0.0 or normB == 0.0:
        return None
    else:
        return dot_product / ((normA * normB) ** 0.5)


def doc_list2str(doc_list):
    """
    transform the doc_list to str
    """
    docu_str = ""
    for wordlist in doc_list:
        docu_str += " ".join(wordlist)
    return docu_str


def MMR(doc_list,corpus):
    """
    input ：corpus and the docment you want to extract
    output :the abstract of the docment
    """
    Corpus = corpus
    docu = doc_list2str(doc_list)
    doc_vec = encode_sen(docu,Corpus)
    QDScore = {}
    ###calculate the  similarity of every sentence with the whole corpus
    for sen in doc_list:
        sen = " ".join(sen)

        sen_vec = encode_sen(sen,corpus)
        score = cosin_distance(sen_vec,doc_vec)
        QDScore[sen] = score


    n = 2
    alpha = 0.7
    Summary_set = []
    while n > 0:
        MMRScore = {}
        ### select the first sentence of abstract
        if Summary_set == []:
            selected = max(QDScore.items(), key=operator.itemgetter(1))[0]
            Summary_set.append(selected)

        Summary_set_str = " ".join(Summary_set)

        for sentence in QDScore.keys():
             #calculate MMR
            if sentence not in Summary_set:
                sum_vec = encode_sen(Summary_set_str, corpus)
                sentence_vec = encode_sen(sentence,corpus)
                MMRScore[sentence] = alpha * QDScore[sentence] - (1 - alpha) * cosin_distance(sentence_vec,sum_vec)
        selected = max(MMRScore.items(), key=operator.itemgetter(1))[0]
        Summary_set.append(selected)
        n -= 1
    # print(len(Summary_set))
    return  Summary_set

# %%
import jieba
sen_list = docment.strip().split("。")
# sen_list.remove("")
doc_list = [jieba.lcut(i) for i in sen_list]
corpus = [" ".join(i) for i in doc_list]

# %%
res = ''
for s in MMR(doc_list,corpus):
    res += s.replace(' ', '')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-72f94756699d> in <module>
#       1 res = ''
# ----> 2 for s in MMR(doc_list,corpus):
#       3     res += s
#
# <ipython-input-19-2bf2256e5dcb> in MMR(doc_list, corpus)
#      69         ### select the first sentence of abstract
#      70         if Summary_set == []:
# ---> 71             selected = max(QDScore.items(), key=operator.itemgetter(1))[0]
#      72             Summary_set.append(selected)
#      73
#
# TypeError: '<' not supported between instances of 'float' and 'NoneType'

# %%
res
